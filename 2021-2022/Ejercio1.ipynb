# %%
import numpy             as np
import cv2               as cv
import matplotlib.pyplot as plt

from skimage import io

img = io.imread("../images/monty-python1.jpg")

plt.imshow(img);

# %%
#img2 = img[100:200, 100:200]
img2 = img[100:200, 100:200, [2,1,0]]
plt.imshow(img2)

# %%
img3 = cv.hconcat([img2]*3)
img3 = cv.vconcat([img3]*3)
plt.imshow(img3)
